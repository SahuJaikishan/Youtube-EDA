# %% [markdown]
# ### 1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
Data=pd.read_csv("youtube_dislike_dataset.csv")
Data
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
Data.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
Data.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# ### 2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
Data.shape
# Out:
# (37422, 12)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %% [markdown]
# #### Inferences:
#
# Columns:
#
# video_id: Identifier for the YouTube video (object data type).
# title: Title of the YouTube video (object data type).
# channel_id: Identifier for the YouTube channel (object data type).
# channel_title: Title of the YouTube channel (object data type).
# published_at: Date and time when the video was published (object data type).
# view_count: Number of views for the video (integer data type).
# likes: Number of likes for the video (integer data type).
# dislikes: Number of dislikes for the video (integer data type).
# comment_count: Number of comments on the video (integer data type).
# tags: Tags associated with the video (object data type).
# description: Description of the video (object data type).
# comments: Comments on the video (object data type). Data Entries:
#
# The DataFrame has 37,422 entries (rows). All columns have 37,422 non-null entries, indicating that there are no missing values in those columns. The 'comments' column has 37264 non-null entries, suggesting that there are some missing values in this column.
#
# Shape of the Dataset:
# Number of Rows: 37,422
# Number of Columns: 12
#
# Data Types:
# The data types include objects (likely strings) for textual information and integers for numerical information.
#
# Data Size:
# The DataFrame has a RangeIndex with 37,422 entries, ranging from 0 to 37421.

# %% [markdown]
# ### 3. Check for the Percentage of the missing values and drop or impute them

# %%
Data.isnull().sum()*100/len(Data)
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %%
Data.dropna(inplace=True)

# %%
Data.isnull().sum()
# Out:
# video_id         0
# title            0
# channel_id       0
# channel_title    0
# published_at     0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# tags             0
# description      0
# comments         0
# dtype: int64

# %% [markdown]
# ### 4. Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
Data.describe()
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.726400e+04  3.726400e+04  3.726400e+04   3.726400e+04
# mean   5.710821e+06  1.672867e+05  4.996434e+03   9.966953e+03
# std    2.431304e+07  5.384931e+05  3.075194e+04   1.173465e+05
# min    2.036800e+04  2.200000e+01  3.000000e+00   1.000000e+00
# 25%    5.141305e+05  1.331725e+04  2.827500e+02   9.140000e+02
# 50%    1.321860e+06  4.255600e+04  7.980000e+02   2.347000e+03
# 75%    3.674527e+06  1.309665e+05  2.466250e+03   6.212000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
Data.select_dtypes(include="object").describe()
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37264  37264                     37264                37264
# unique        37264  36958                     10891                10813
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description  \
# count                 37264  37264       37264
# unique                36617  28705       35479
# top     2020-10-16 04:00:10
# freq                      6   3808         587
#
#                                                  comments
# count                                               37264
# unique                                              37264
# top     Respect to Dortmund fans,must be sad losing hi...
# freq                                                    1

# %% [markdown]
# #### View Count: Inferences
# The number of views ranges from a minimum of 20,368 to a maximum of approximately 1.32 billion. The average number of views is around 5.71 million. The distribution suggests that there are videos with significantly higher view counts, potentially indicating popular content. Likes:
#
# The number of likes varies widely, with a minimum of 22 and a maximum of approximately 31.84 million. On average, videos receive around 167,287 likes. The distribution shows that some videos have a substantial number of likes, indicating a diverse range of audience preferences. Dislikes:
#
# Dislikes range from a minimum of 3 to a maximum of approximately 2.40 million. The average number of dislikes is around 4,996. The distribution suggests that while most videos have a relatively low number of dislikes, there are videos with a higher count. Comment Count:
#
# The number of comments varies, with a minimum of 1 and a maximum of approximately 16.07 million. On average, videos receive around 9,967 comments. The distribution indicates that there is a wide range of audience interaction, with some videos generating a significant amount of discussion.
#
# df.select_dtypes(include="object").describe()

# %% [markdown]
# ### 5. Convert datatype of column published_at from object to pandas datetime

# %%
Data["published_at"]=pd.to_datetime(Data["published_at"])

# %%
Data.dtypes
# Out:
# video_id                 object
# title                    object
# channel_id               object
# channel_title            object
# published_at     datetime64[ns]
# view_count                int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# tags                     object
# description              object
# comments                 object
# dtype: object

# %% [markdown]
# ### 6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
Data['published_month']=Data["published_at"].dt.month

# %%
Data.head(2)
# Out:
#       video_id                                 title  \
# 0  --0bCF-iK2E  Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs    Migos - Avalanche (Official Video)
#
#                  channel_id channel_title        published_at  view_count  \
# 0  UC6UL29enLNe4mqwTfAyeNuw    Bundesliga 2021-07-01 10:00:00     1048888
# 1  UCGIelM2Dj3zza3xyV3pL3WQ     MigosVEVO 2021-06-10 16:00:00    15352638
#
#     likes  dislikes  comment_count  \
# 0   19515       226           1319
# 1  359277      7479          18729
#
#                                                 tags  \
# 0  football soccer ftbol alemn Bundesliga season ...
# 1  Migos Avalanche Quality Control Music/Motown R...
#
#                                          description  \
# 0  Enjoy the best skills and goals from Jadon San...
# 1  Watch the the official video for Migos - "Aval...
#
#                                             comments  published_month
# ...

# %%
Data['published_month'].nunique()
# Out:
# 12

# %% [markdown]
# ### 7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb' and so on.....

# %%
Data['published_month']=Data["published_at"].dt.month_name()

# %%
Data.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title        published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga 2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO 2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy 2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1 2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering 2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %% [markdown]
# ### 8. Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
pd.DataFrame(Data.groupby("published_month")["video_id"].count()).sort_values(by="video_id",ascending=False)
# Out:
#                  video_id
# published_month
# October              4976
# September            4854
# November             4821
# August               4250
# December             3063
# July                 2331
# June                 2305
# March                2248
# February             2125
# April                2119
# January              2099
# May                  2073

# %% [markdown]
# ### 9. Find the count of unique video_id, channel_id and channel_title.

# %%
pd.DataFrame(Data["video_id"].unique()).count()
# Out:
# 0    37264
# dtype: int64

# %%
pd.DataFrame(Data["channel_id"].unique()).count()
# Out:
# 0    10891
# dtype: int64

# %%
pd.DataFrame(Data["channel_title"].unique()).count()
# Out:
# 0    10813
# dtype: int64

# %% [markdown]
# ### 10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

# %%
pd.DataFrame(Data.groupby("channel_id")["video_id"].count()).sort_values(by="video_id",ascending=False).head(10)
# Out:
#                           video_id
# channel_id
# UCNAf1k0yIjyGu3k9BwAg3lg       533
# UCMmVPVb0BwSIOWVeDwlPocQ       301
# UC4i_9WvfPRTuRWEaWyfKuFw       246
# UCWJ2lWNubArHWmf3FIHbfcQ       209
# UCDVYQ4Zhbm3S2dlz7P1GBDg       162
# UCJ5v_MCY6GNUBTO8-D3XoAg       122
# UCpB959t8iPrxQWj7G6n0ctQ        99
# UCke6I9N4KfC968-yRcd5YRg        98
# UCB_qr75-ydFVKSF9Dmo6izg        87
# UCqFMzb-4AUf6WAIbl132QKA        86

# %%
pd.DataFrame(Data.groupby("channel_id")["video_id"].count()).sort_values(by="video_id",ascending=False).tail(10)
# Out:
#                           video_id
# channel_id
# UCbzpLjxymlYhxPgKJwrtJuw         1
# UCbz_LB6vGKahwEjZxks0sNQ         1
# UCKywdPuazt_1gEqxZ4D8aFA         1
# UC52eqDe6TTYp77sCp2Hnj6Q         1
# UC9gPwVGWqT8xkArzQ2PB0jA         1
# UCbyXypnP1BDzMvOA7GyR8TQ         1
# UCbySksOlV461eicpIf30j5Q         1
# UC52r8QwD9YwZeuxjizFLGqw         1
# UC53bIpnef1pwAx69ERmmOLA         1
# UCC3OGYxHwV8pB5yLobw9KdA         1

# %% [markdown]
# ### 11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
pd.DataFrame(Data.groupby("video_id")["likes"].max()).sort_values(by="likes",ascending=False).head(1)
# Out:
#                 likes
# video_id
# gdZLi9oWNZg  31837675

# %%
pd.DataFrame(Data.groupby("video_id")["likes"].min()).sort_values(by="likes").head(1)
# Out:
#              likes
# video_id
# cfP1eeNPT_E     22

# %% [markdown]
# ### 12. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
pd.DataFrame(Data.groupby("video_id")["dislikes"].max()).sort_values(by="dislikes",ascending=False).head(1)
# Out:
#              dislikes
# video_id
# M0O7lLe4SmA   2397733

# %%
pd.DataFrame(Data.groupby("video_id")["dislikes"].min()).sort_values(by="dislikes").head(1)
# Out:
#              dislikes
# video_id
# mFK01TbgDuo         3

# %% [markdown]
# #### Inferences:
#
# The video with the video_id "M0O7lLe4SmA" has an exceptionally high number of dislikes, indicating that it might have received significant negative feedback or controversy.
# On the other hand, the video with the video_id "mFK01TbgDuo" has a very low number of dislikes, suggesting that it received positive feedback or had a low level of controversy.

# %% [markdown]
# ### 13. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
Data.dtypes
# Out:
# video_id                   object
# title                      object
# channel_id                 object
# channel_title              object
# published_at       datetime64[ns]
# view_count                  int64
# likes                       int64
# dislikes                    int64
# comment_count               int64
# tags                       object
# description                object
# comments                   object
# published_month            object
# dtype: object

# %%
Data.select_dtypes(include="number").corr()
# Out:
#                view_count     likes  dislikes  comment_count
# view_count       1.000000  0.784199  0.684576       0.464442
# likes            0.784199  1.000000  0.679668       0.581117
# dislikes         0.684576  0.679668  1.000000       0.391999
# comment_count    0.464442  0.581117  0.391999       1.000000

# %%
sns.scatterplot(data=Data,x="view_count",y="dislikes")
# Out:
# <Axes: xlabel='view_count', ylabel='dislikes'>

# %% [markdown]
# ### 14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

# %%
Data1=Data.groupby("published_month")

# %%
Data2=Data1.get_group("January")
Data2
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
Data2['video_id'].count()
# Out:
# 2099
